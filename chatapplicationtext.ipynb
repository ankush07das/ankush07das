# %% [markdown]
# <a href="https://colab.research.google.com/github/ankush07das/ankush07das/blob/main/chatapplicationtext.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q openai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 1.8 MB/s eta 0:00:00

# %%
import openai
messages=[
    {"role":"system","content":"You are a kind helpful assistant."}
]
openai.api_key ='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'

# %%
while True:
    message = input("User : ")
    if message:
        messages.append({"role": "user", "content": message},)
        chat = openai.ChatCompletion.create(
            model="gpt-3.5-turbo", messages=messages
        )

    reply = chat.choices[0].message.content
    print(f"ChatGPT: {reply}")
    messages.append({"role": "assistant", "content": reply})
# Out:
# User : I am a female , do i get the same share of property like my brother in India?
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8d6459b161e9> in <cell line: 1>()
#       2     message = input("User : ")
#       3     if message:
# ----> 4         messages.append({"role": "user", "content": message},)
#       5         chat = openai.ChatCompletion.create(
#       6             model="gpt-3.5-turbo", messages=messages
#
# NameError: name 'messages' is not defined

# %%
import requests
import openai
openai.api_key ='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'

URL = "https://api.openai.com/v1/chat/completions"

payload = {
"model": "gpt-3.5-turbo",
"messages": [{"role": "user", "content": f"I am a female ,do i get the same share like my brother in India?"}],
"temperature" : 1.0,
"top_p":1.0,
"n" : 1,
"stream": False,
"presence_penalty":0,
"frequency_penalty":0,
}

headers = {
"Content-Type": "application/json",
"Authorization": f"Bearer {openai.api_key}"
}

response = requests.post(URL, headers=headers, json=payload, stream=False)
response.content
# Out:
# b'data: {"id":"chatcmpl-7zrQ7nU9SNYefj4agBLQSPunrJx6p","object":"chat.completion.chunk","created":1694977711,"model":"gpt-3.5-turbo-0613","choices":[{"index":0,"delta":{"role":"assistant","content":""},"finish_reason":null}]}\n\ndata: {"id":"chatcmpl-7zrQ7nU9SNYefj4agBLQSPunrJx6p","object":"chat.completion.chunk","created":1694977711,"model":"gpt-3.5-turbo-0613","choices":[{"index":0,"delta":{"content":"In"},"finish_reason":null}]}\n\ndata: {"id":"chatcmpl-7zrQ7nU9SNYefj4agBLQSPunrJx6p","object":"chat.completion.chunk","created":1694977711,"model":"gpt-3.5-turbo-0613","choices":[{"index":0,"delta":{"content":" India"},"finish_reason":null}]}\n\ndata: {"id":"chatcmpl-7zrQ7nU9SNYefj4agBLQSPunrJx6p","object":"chat.completion.chunk","created":1694977711,"model":"gpt-3.5-turbo-0613","choices":[{"index":0,"delta":{"content":","},"finish_reason":null}]}\n\ndata: {"id":"chatcmpl-7zrQ7nU9SNYefj4agBLQSPunrJx6p","object":"chat.completion.chunk","created":1694977711,"model":"gpt-3.5-turbo-0613","choices":[{"index":0,"delta":{"content":" the"},"finish_reason":null}]}\n\ndata: {"id":"chatcmpl-7zrQ7nU9SNYefj4agBLQSPunrJx6p","object":"chat.completion.chunk","created":1694977711,"model":"gpt-3.5-turbo-0613","choices":[{"index":0,"delta":{"content":" legal"},"finish_reason":null}]}\n\ndata: {"id":"chatcmpl-7zrQ7nU9SNYefj4agBLQSPunrJx6p","object":"chat.completion.chunk","created":1694977711,"model":"gpt-3.5-turbo-0613","choices":[{"index":0,"delta":{"content":" provisions"},"finish_reason":null}]}\n\ndata: {"id":"chatcmpl-7zrQ7nU9SNYefj4agBLQSPunrJx6p","object":"chat.completion.chunk","created":1694977711,"model":"gpt-3.5-turbo-0613","choices":[{"index":0,"delta":{"content":" for"},"finish_reason":null}]}\n\ndata: {"id":"chatcmpl-7zrQ7nU9SNYefj4agBLQSPunrJx6p","object":"chat.completion.chunk","created":1694977711,"model":"gpt-3.5-turbo-0613","choices":[{"index":0,"delta":{"content":" inheritance"},"finish_reason":null}]}\n\ndata: {"id":"chatcmpl-7zrQ7nU9SNYefj4agBLQSPunrJx6p","object":"chat.completion.chunk","created":1694977711,"model":"gpt-3.5-turbo-0613","choices":[{"index":0,"delta":{"content":" differ"},"finish_reason":null}]}\n\ndata: {"id":"chatcmpl-7zrQ7nU9SNYefj4agBLQSPunrJx6p","object":"chat.completion.chunk","created":1694977711,"model":"gpt-3.5-turbo-0613","choices":[{"index":0,"delta":{"content":" depending"},"finish_reason":null}]}\n\ndata: {"id":"chatcmpl-7zrQ7nU9SNYefj4agBLQSPunrJx6p","object":"chat.completion.chunk","created":1694977711,"model":"gpt-3.5-turbo-0613","choices":[{"index":0,"delta":{"content":" on"},"finish_reason":null}]}\n\ndata: {"id":"chatcmpl-7zrQ7nU9SNYefj4agBLQSPunrJx6p","object":"chat.completion.chunk","created":1694977711,"model":"gpt-3.5-turbo-0613","choices":[{"index":0,"delta":{"content":" various"},"finish_reason":null}]}\n\ndata: {"id":"chatcmpl-7zrQ7nU9SNYefj4agBLQSPunrJx6p","object":"chat.completion.chunk","created":1694977711,"model":"gpt-3.5-turbo-0613","choices":[{"index":0,"delta":{"content":" factors"},"finish_reason":null}]}\n\ndata: {"id":"chatcmpl-7zrQ7nU9SNYefj4agBLQSPunrJx6p","object":"chat.completion.chunk","created":1694977711,"model":"gpt-3.5-turbo-0613","choices":[{"index":0,"delta":{"content":" including"},"finish_reason":null}]}\n\ndata: {"id":"chatcmpl-7zrQ7nU9SNYefj4agBLQSPunrJx6p","object":"chat.completion.chunk","created":1694977711,"model":"gpt-3.5-turbo-0613","choices":[{"index":0,"delta":{"content":" religion"},"finish_reason":null}]}\n\ndata: {"id":"chatcmpl-7zrQ7nU9SNYefj4agBLQSPunrJx6p","object":"chat.completion.chunk","created":1694977711,"model":"gpt-3.5-turbo-0613","choices":[{"index":0,"delta":{"content":" and"},"finish_reason":null}]}\n\ndata: {"id":"chatcmpl-7zrQ7nU9SNYefj4agBLQSPunrJx6p","object":"chat.completion.chunk","created":1694977711,"model":"gpt-3.5-turbo-0613","choices":[{"index":0,"delta":{"content":" personal"},"finish_reason":null}]}\n\ndata: {"id":"chatcmpl-7zrQ7nU9SNYefj4agBLQSPunrJx6p","object":"chat.completion.chunk","created":1694977711,"model":"gpt-3 ...
